# %% [markdown]
# # Exploring the Datasets
# *Authors: Angelika Shastapalava, Excel Espina, David Hadaller, Sam Mundle*
#
# ### What are we using:
# 1) The "Discovery" API is MTA's official developer resource to get real-time data from their NYC Bus Time service. You can get more information <a href="http://bustime.mta.info/wiki/Developers/Index">here</a>
# 2) Kaggle's NYC Bus Data <a href="https://www.kaggle.com/stoney71/new-york-city-transport-statistics">here</a>
#
# ### How are we using it:
# Using regression and classification techniques learned in class, we want to explore the following:
# > 1. Based on a ~10 stops/lines how closely do the actual stop times reflect the posted bus
# schedules and what is the distribution around the scheduled time that busses actually
# arrive?
# >2. What environmental factors impact a buses schedule? What impact does time of day,
# temperature, and weather have?
# >3. What socioeconomic factors play into a buses schedule? Do we see better or worse
# availability in neighborhoods with different average incomes?
# >4. Predicting with a defined degree certainty if a bus is coming within a given time frame
#
# ### Sections:
# 1) [Loading the Datasets](#Loading-the-Datasets)
# 2) [Cleaning the Data](#Cleaning-the-Data)
# 3) [Visualizing the Data](#Visualizing-the-Data)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %% [markdown]
# ### Loading the Datasets
# We want to work with the Kaggle dataset so head over <a href="https://www.kaggle.com/stoney71/new-york-city-transport-statistics">here</a> and download the zip file. (A word of caution: the dataset is approx **5GB** when extracted!)
#
# After you extract the data, we want to load a csv on our notebook.
#
# The `error_bad_lines=False` parameter fixes some formatting issues when we load in our dataset.

# %%
# %%capture
mta = pd.read_csv('mta_1708.csv', error_bad_lines=False)
# mta.set_index('PublishedLineName', inplace=True)

# %%
mta.head()
# Out:
#         RecordedAtTime  DirectionRef PublishedLineName         OriginName  \
# 0  2017-08-01 00:01:03             0               Q32       W 32 ST/7 AV
# 1  2017-08-01 00:00:52             0               B35         39 ST/1 AV
# 2  2017-08-01 00:01:18             1               Q83      227 ST/113 DR
# 3  2017-08-01 00:01:05             0           M60-SBS  BROADWAY/W 106 ST
# 4  2017-08-01 00:01:05             0           M60-SBS  BROADWAY/W 106 ST
#
#    OriginLat  OriginLong                        DestinationName  \
# 0  40.749405  -73.991020  JACKSON HTS NORTHERN - 81 via ROOSVLT
# 1  40.656456  -74.012245     BROWNSVILLE M GASTON BL via CHURCH
# 2  40.702263  -73.730339     JAMAICA HILLSIDE - 153 via LIBERTY
# 3  40.801819  -73.967644  SELECT BUS SERVICE LA GUARDIA AIRPORT
# 4  40.801819  -73.967644  SELECT BUS SERVICE LA GUARDIA AIRPORT
#
#    DestinationLat  DestinationLong VehicleRef  VehicleLocation.Latitude  \
# 0       40.755322       -73.886139  NYCT_7424                 40.749403
# 1       40.656345       -73.907188   NYCT_406                 40.651330
# 2       40.706795       -73.804100  NYCT_6449                 40.706532
# 3       40.768074       -73.862091  NYCT_5846                 40.770403
# 4       40.768074       -73.862091  NYCT_5846                 40.770403
#
#    VehicleLocation.Longitude           NextStopPointName ArrivalProximityText  \
# 0                 -73.990841  W 32 ST/AV OF THE AMERICAS        < 1 stop away
# 1                 -73.938960           CHURCH AV/E 42 ST          approaching
# 2                 -73.804177          153 ST/HILLSIDE AV              at stop
# 3                 -73.917687               HOYT AV/31 ST       4.1 miles away
# 4                 -73.917687               HOYT AV/31 ST       4.1 miles away
#
#    DistanceFromStop  ExpectedArrivalTime ScheduledArrivalTime
# 0             220.0  2017-08-01 00:01:37             24:01:11
# 1             107.0  2017-08-01 00:02:00             23:56:12
# 2              25.0  2017-08-01 00:01:27             24:00:00
# 3            6519.0  2017-08-01 00:06:47             23:39:14
# 4            6519.0  2017-08-01 00:06:47             23:44:32

# %%
mta.dtypes
# Out:
# RecordedAtTime                object
# DirectionRef                   int64
# PublishedLineName             object
# OriginName                    object
# OriginLat                    float64
# OriginLong                   float64
# DestinationName               object
# DestinationLat               float64
# DestinationLong              float64
# VehicleRef                    object
# VehicleLocation.Latitude     float64
# VehicleLocation.Longitude    float64
# NextStopPointName             object
# ArrivalProximityText          object
# DistanceFromStop             float64
# ExpectedArrivalTime           object
# ScheduledArrivalTime          object
# dtype: object

# %% [markdown]
# ## Cleaning the Data
# For this EDA, we're only going to be looking at the M100 bus going to

# %% [markdown]
# First things first: convert ```ExpectedArrivalTime```'s Timestamp format to just the time itself.
#
# Then we need to adjust the ```ScheduledArrivalTime``` to match python's time range of 0-23 hours. Here we pass ```errors='coerce'``` parameter to convert troublesome or out of range times to NaT (Not a Time).

# %%
mta = mta[mta['VehicleRef'] == 'NYCT_7424']

#tips = tips[tips['time'] == 'Dinner'].head(5)

df1 = mta[mta['DirectionRef'] == 0]
df2 = mta[mta['DirectionRef'] == 1]

#tips[['total_bill', 'tip', 'smoker', 'time']].head(5)
df1 = df1[['DestinationName','DirectionRef']].rename(columns={'DestinationName':'Dest1','DirectionRef':'Dir1'})
df2 = df2[['DestinationName','DirectionRef']].rename(columns={'DestinationName':'Dest2','DirectionRef':'Dir2'})

pd.concat([df1, df2], axis=1)
# Out:
#                                          Dest1  Dir1  \
# 0        JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 788      JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 1551     JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 2267     JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 2959     JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 3580     JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 4185     JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 23889                                      NaN   NaN
# 25921                                      NaN   NaN
# 28118                                      NaN   NaN
# 30529                                      NaN   NaN
# 33051                                      NaN   NaN
# 35777                                      NaN   NaN
# 38599                                      NaN   NaN
# 41543                                      NaN   NaN
# 44589         COLLEGE PT via MAIN ST via 20 AV   0.0
# 47680         COLLEGE PT via MAIN ST via 20 AV   0.0
# 50750         COLLEGE PT via MAIN ST via 20 AV   0.0
# 53808         COLLEGE PT via MAIN ST via 20 AV   0.0
# 56836         COLLEGE PT via MAIN ST via 20 AV   0.0
# 59808         COLLEGE PT via MAIN ST via 20 AV   0.0
# 62714         COLLEGE PT via MAIN ST via 20 AV   0.0
# 65523         COLLEGE PT via MAIN ST via 20 AV   0.0
# 68188         COLLEGE PT via MAIN ST via 20 AV   0.0
# 70739                                      NaN   NaN
# 73181                                      NaN   NaN
# 75540                                      NaN   NaN
# 77827                                      NaN   NaN
# 80034                                      NaN   NaN
# 82171                                      NaN   NaN
# ...                                        ...   ...
# 6370982  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6373145  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6375324  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6377539  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6379797  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6382062                                    NaN   NaN
# 6384364                                    NaN   NaN
# 6386715                                    NaN   NaN
# 6389152                                    NaN   NaN
# 6391609                                    NaN   NaN
# 6396630                                    NaN   NaN
# 6399197                                    NaN   NaN
# 6401810                                    NaN   NaN
# 6404471                                    NaN   NaN
# 6407199  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6409951  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6412736  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6415528  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6418387  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6421262  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6424148  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6427071  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6430004  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6432916  JACKSON HTS NORTHERN - 81 via ROOSVLT   0.0
# 6449571                                    NaN   NaN
# 6452127                                    NaN   NaN
# 6454573                                    NaN   NaN
# 6456907                                    NaN   NaN
# 6459177                                    NaN   NaN
# 6461384                                    NaN   NaN
#
#                                             Dest2  Dir2
# 0                                             NaN   NaN
# 788                                           NaN   NaN
# 1551                                          NaN   NaN
# 2267                                          NaN   NaN
# 2959                                          NaN   NaN
# 3580                                          NaN   NaN
# 4185                                          NaN   NaN
# 23889    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 25921    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 28118    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 30529    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 33051    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 35777    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 38599    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 41543    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 44589                                         NaN   NaN
# 47680                                         NaN   NaN
# 50750                                         NaN   NaN
# 53808                                         NaN   NaN
# 56836                                         NaN   NaN
# 59808                                         NaN   NaN
# 62714                                         NaN   NaN
# 65523                                         NaN   NaN
# 68188                                         NaN   NaN
# 70739    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 73181    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 75540    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 77827    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 80034    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# 82171    JAMAICA MERRICK BL via 14 AV via MAIN ST   1.0
# ...                                           ...   ...
# 6370982                                       NaN   NaN
# 6373145                                       NaN   NaN
# 6375324                                       NaN   NaN
# 6377539                                       NaN   NaN
# 6379797                                       NaN   NaN
# 6382062                           MIDTOWN PENN ST   1.0
# 6384364                           MIDTOWN PENN ST   1.0
# 6386715                           MIDTOWN PENN ST   1.0
# 6389152                           MIDTOWN PENN ST   1.0
# 6391609                           MIDTOWN PENN ST   1.0
# 6396630                           MIDTOWN PENN ST   1.0
# 6399197                           MIDTOWN PENN ST   1.0
# 6401810                           MIDTOWN PENN ST   1.0
# 6404471                           MIDTOWN PENN ST   1.0
# 6407199                                       NaN   NaN
# 6409951                                       NaN   NaN
# 6412736                                       NaN   NaN
# 6415528                                       NaN   NaN
# 6418387                                       NaN   NaN
# 6421262                                       NaN   NaN
# 6424148                                       NaN   NaN
# 6427071                                       NaN   NaN
# 6430004                                       NaN   NaN
# 6432916                                       NaN   NaN
# 6449571                           MIDTOWN PENN ST   1.0
# 6452127                           MIDTOWN PENN ST   1.0
# 6454573                           MIDTOWN PENN ST   1.0
# 6456907                           MIDTOWN PENN ST   1.0
# 6459177                           MIDTOWN PENN ST   1.0
# 6461384                           MIDTOWN PENN ST   1.0
#
# [1920 rows x 4 columns]

# %%
mta.head(20)
# Out:
#            RecordedAtTime  DirectionRef PublishedLineName         OriginName  \
# 225   2017-08-01 00:01:04             1              M100  BROADWAY/W 219 ST
# 234   2017-08-01 00:00:53             0              M100        1 AV/125 ST
# 346   2017-08-01 00:01:08             1              M100  BROADWAY/W 219 ST
# 548   2017-08-01 00:01:09             1              M100  BROADWAY/W 219 ST
# 762   2017-08-01 00:01:25             0              M100        1 AV/125 ST
# 1005  2017-08-01 00:11:28             1              M100  BROADWAY/W 219 ST
# 1014  2017-08-01 00:11:37             0              M100        1 AV/125 ST
# 1121  2017-08-01 00:11:35             1              M100  BROADWAY/W 219 ST
# 1523  2017-08-01 00:11:39             0              M100        1 AV/125 ST
# 1754  2017-08-01 00:21:06             1              M100  BROADWAY/W 219 ST
# 1762  2017-08-01 00:21:06             0              M100        1 AV/125 ST
# 1862  2017-08-01 00:21:01             1              M100  BROADWAY/W 219 ST
# 2471  2017-08-01 00:31:03             1              M100  BROADWAY/W 219 ST
# 2480  2017-08-01 00:30:45             0              M100        1 AV/125 ST
# 2571  2017-08-01 00:31:00             1              M100  BROADWAY/W 219 ST
# 2751  2017-08-01 00:30:47             0              M100        1 AV/125 ST
# 2752  2017-08-01 00:30:47             0              M100        1 AV/125 ST
# 3138  2017-08-01 00:41:31             1              M100  BROADWAY/W 219 ST
# 3147  2017-08-01 00:41:46             0              M100        1 AV/125 ST
# 3232  2017-08-01 00:41:29             0              M100        1 AV/125 ST
#
#       OriginLat  OriginLong                           DestinationName  \
# 225   40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 234   40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
# 346   40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 548   40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 762   40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
# 1005  40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 1014  40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
# 1121  40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 1523  40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
# 1754  40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 1762  40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
# 1862  40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 2471  40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 2480  40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
# 2571  40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 2751  40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
# 2752  40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
# 3138  40.871967  -73.913040  E HARLM 1 AV-125 ST via BDWY via AMSTRDM
# 3147  40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
# 3232  40.801968  -73.931358      INWOOD 220 ST via AMSTERDAM via BWAY
#
#       DestinationLat  DestinationLong VehicleRef  VehicleLocation.Latitude  \
# 225        40.802273       -73.931145  NYCT_8366                 40.872595
# 234        40.871902       -73.913101  NYCT_4368                 40.810075
# 346        40.802273       -73.931145  NYCT_8375                 40.854328
# 548        40.802273       -73.931145  NYCT_8388                 40.809137
# 762        40.871902       -73.913101  NYCT_4349                 40.851938
# 1005       40.802273       -73.931145  NYCT_8366                 40.869532
# 1014       40.871902       -73.913101  NYCT_4368                 40.827159
# 1121       40.802273       -73.931145  NYCT_8375                 40.839757
# 1523       40.871902       -73.913101  NYCT_4349                 40.859447
# 1754       40.802273       -73.931145  NYCT_8366                 40.861532
# 1762       40.871902       -73.913101  NYCT_4368                 40.840707
# 1862       40.802273       -73.931145  NYCT_8375                 40.824719
# 2471       40.802273       -73.931145  NYCT_8366                 40.840660
# 2480       40.871902       -73.913101  NYCT_4368                 40.859160
# 2571       40.802273       -73.931145  NYCT_8375                 40.809266
# 2751       40.871902       -73.913101  NYCT_8388                 40.820274
# 2752       40.871902       -73.913101  NYCT_8388                 40.820274
# 3138       40.802273       -73.931145  NYCT_8366                 40.824893
# 3147       40.871902       -73.913101  NYCT_4368                 40.868765
# 3232       40.871902       -73.913101  NYCT_8375                 40.804519
#
#       VehicleLocation.Longitude          NextStopPointName  \
# 225                  -73.912298                9 av/218 st
# 234                  -73.950935  W 125 ST/FRED DOUGLASS BL
# 346                  -73.933650          BROADWAY/W 187 ST
# 548                  -73.948722  W 125 ST/ADAM C POWELL BL
# 762                  -73.934836          BROADWAY/W 185 ST
# 1005                 -73.915142             10 AV/W 214 ST
# 1014                 -73.946196      AMSTERDAM AV/W 149 ST
# 1121                 -73.940335    W 166 ST/ST NICHOLAS AV
# 1523                 -73.922601      10 AV/HARLEM RIVER DR
# 1754                 -73.930241        BROADWAY/BENNETT AV
# 1762                 -73.939571    ST NICHOLAS AV/W 167 ST
# 1862                 -73.947981      AMSTERDAM AV/W 143 ST
# 2471                 -73.940068    W 166 ST/ST NICHOLAS AV
# 2480                 -73.931374          BROADWAY/W 196 ST
# 2571                 -73.949028  W 125 ST/ADAM C POWELL BL
# 2751                 -73.951234      AMSTERDAM AV/W 138 ST
# 2752                 -73.951234      AMSTERDAM AV/W 138 ST
# 3138                 -73.947854      AMSTERDAM AV/W 143 ST
# 3147                 -73.915769             10 AV/W 215 ST
# 3232                 -73.937764      E 125 ST/LEXINGTON AV
#
#      ArrivalProximityText  DistanceFromStop  ExpectedArrivalTime  \
# 225         < 1 stop away             211.0  2017-08-01 00:01:26
# 234           approaching              67.0  2017-08-01 00:01:27
# 346           approaching              51.0                  NaN
# 548           approaching              88.0  2017-08-01 00:01:29
# 762           approaching             143.0  2017-08-01 00:01:50
# 1005          approaching              76.0  2017-08-01 00:11:51
# 1014          approaching             123.0  2017-08-01 00:12:21
# 1121              at stop              18.0                  NaN
# 1523              at stop              18.0  2017-08-01 00:11:52
# 1754        < 1 stop away             200.0  2017-08-01 00:21:37
# 1762              at stop              25.0  2017-08-01 00:21:16
# 1862          approaching             141.0                  NaN
# 2471          approaching             147.0  2017-08-01 00:32:13
# 2480        < 1 stop away             205.0  2017-08-01 00:31:41
# 2571          approaching             117.0                  NaN
# 2751          approaching             101.0  2017-08-01 00:31:17
# 2752          approaching             101.0  2017-08-01 00:31:17
# 3138        < 1 stop away             163.0  2017-08-01 00:42:24
# 3147          approaching              71.0                  NaN
# 3232              at stop               3.0                  NaN
#
#      ScheduledArrivalTime
# 225              24:08:49
# 234              23:55:18
# 346              23:55:20
# 548              23:55:52
# 762              23:57:26
# 1005             24:10:29
# 1014             24:06:52
# 1121             24:03:47
# 1523             24:08:48
# 1754             24:21:36
# 1762             24:14:01
# 1862             24:12:57
# 2471             24:31:44
# 2480             24:22:53
# 2571             24:21:52
# 2751             24:26:14
# 2752             24:27:14
# 3138             24:39:57
# 3147             24:34:57
# 3232             24:38:03

# %%
### Removing Date from the ExpectedArrivalTime

# Convert object to datetime64 
mta['expected_time'] = pd.to_datetime(mta['ExpectedArrivalTime']).dt.time
mta['scheduled_time'] = pd.to_datetime(mta['ScheduledArrivalTime'],format='%H:%M:%S', errors='coerce').dt.time
# mta['scheduled_time'] = pd.to_datetime(mta['scheduled_time'])
# temp = pd.to_datetime(mta['scheduled_time']).dt.time
# datetime.datetime.strptime().time()
mta.infer_objects().dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-2abbdbba9c9e> in <module>()
#       7 # temp = pd.to_datetime(mta['scheduled_time']).dt.time
#       8 # datetime.datetime.strptime().time()
# ----> 9 mta.infer_objects().dtypes
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'infer_objects'

# %%
mta.head()
# Out:
#                         RecordedAtTime  DirectionRef         OriginName  \
# PublishedLineName
# Q32                2017-08-01 00:01:03             0       W 32 ST/7 AV
# B35                2017-08-01 00:00:52             0         39 ST/1 AV
# Q83                2017-08-01 00:01:18             1      227 ST/113 DR
# M60-SBS            2017-08-01 00:01:05             0  BROADWAY/W 106 ST
# M60-SBS            2017-08-01 00:01:05             0  BROADWAY/W 106 ST
#
#                    OriginLat  OriginLong  \
# PublishedLineName
# Q32                40.749405  -73.991020
# B35                40.656456  -74.012245
# Q83                40.702263  -73.730339
# M60-SBS            40.801819  -73.967644
# M60-SBS            40.801819  -73.967644
#
#                                          DestinationName  DestinationLat  \
# PublishedLineName
# Q32                JACKSON HTS NORTHERN - 81 via ROOSVLT       40.755322
# B35                   BROWNSVILLE M GASTON BL via CHURCH       40.656345
# Q83                   JAMAICA HILLSIDE - 153 via LIBERTY       40.706795
# M60-SBS            SELECT BUS SERVICE LA GUARDIA AIRPORT       40.768074
# M60-SBS            SELECT BUS SERVICE LA GUARDIA AIRPORT       40.768074
#
#                    DestinationLong VehicleRef  VehicleLocation.Latitude  \
# PublishedLineName
# Q32                     -73.886139  NYCT_7424                 40.749403
# B35                     -73.907188   NYCT_406                 40.651330
# Q83                     -73.804100  NYCT_6449                 40.706532
# M60-SBS                 -73.862091  NYCT_5846                 40.770403
# M60-SBS                 -73.862091  NYCT_5846                 40.770403
#
#                    VehicleLocation.Longitude           NextStopPointName  \
# PublishedLineName
# Q32                               -73.990841  W 32 ST/AV OF THE AMERICAS
# B35                               -73.938960           CHURCH AV/E 42 ST
# Q83                               -73.804177          153 ST/HILLSIDE AV
# M60-SBS                           -73.917687               HOYT AV/31 ST
# M60-SBS                           -73.917687               HOYT AV/31 ST
#
#                   ArrivalProximityText  DistanceFromStop  ExpectedArrivalTime  \
# PublishedLineName
# Q32                      < 1 stop away             220.0  2017-08-01 00:01:37
# B35                        approaching             107.0  2017-08-01 00:02:00
# Q83                            at stop              25.0  2017-08-01 00:01:27
# M60-SBS                 4.1 miles away            6519.0  2017-08-01 00:06:47
# M60-SBS                 4.1 miles away            6519.0  2017-08-01 00:06:47
#
#                   ScheduledArrivalTime expected_time scheduled_time
# PublishedLineName
# Q32                           24:01:11      00:01:37            NaT
# B35                           23:56:12      00:02:00       23:56:12
# Q83                           24:00:00      00:01:27            NaT
# M60-SBS                       23:39:14      00:06:47       23:39:14
# M60-SBS                       23:44:32      00:06:47       23:44:32

# %% [markdown]
# Now let's drop observations whose ```DistanceFromStop``` is farther away than 30 ft.

# %%
mta = mta.loc[(mta['DistanceFromStop']<=30),]
print(mta.shape)
# Out:
# (1856274, 18)

# %% [markdown]
# Now let's drop missing ```ExpectedArrivalTime, expected_time & scheduled_time``` since we can't impute it at the moment.

# %%
mta = mta.loc[(mta['ExpectedArrivalTime'].notnull()),]
mta = mta.loc[(mta['expected_time'].notnull()),]
mta = mta.loc[(mta['scheduled_time'].notnull()),]
print(mta.shape)
# Out:
# (1315851, 18)

# %% [markdown]
# We'll create a new column that calculates the time difference between the expected and scheduled.

# %%
mta['time_diff'] = (pd.to_timedelta(mta['expected_time'].astype(str)) - 
                   pd.to_timedelta(mta['scheduled_time'].astype(str)))

# %%
mta['time_diff_mins'] = ((mta['time_diff'] / np.timedelta64(1, 'm')) + 1440).astype(int)
mta.dtypes
# Out:
# RecordedAtTime                        object
# DirectionRef                           int64
# OriginName                            object
# OriginLat                            float64
# OriginLong                           float64
# DestinationName                       object
# DestinationLat                       float64
# DestinationLong                      float64
# VehicleRef                            object
# VehicleLocation.Latitude             float64
# VehicleLocation.Longitude            float64
# NextStopPointName                     object
# ArrivalProximityText                  object
# DistanceFromStop                     float64
# ExpectedArrivalTime                   object
# ScheduledArrivalTime                  object
# expected_time                         object
# scheduled_time                        object
# time_diff                    timedelta64[ns]
# time_diff_mins                         int32
# dtype: object

# %% [markdown]
# ## Visualizing the Data
#
# Now we can visualize the time difference between expected and scheduled arrival times.

# %%
# TODO

# %% [markdown]
# Looking at MTA API:

# %%
# Key for Excel
mta_key = "51b681ab-bb14-4f29-9104-db15a7a41d41"
