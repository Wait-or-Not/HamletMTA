# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

mta_df = pd.read_csv('M100_month_W125_st.csv', error_bad_lines=False)

# %%
mta_df.sort_values("RecordedAtTime", inplace=True)
mta_df[50:60]
# Out:
#          RecordedAtTime  DirectionRef PublishedLineName   OriginName  \
# 50  2017-08-14 14:26:31             0              M100  1 AV/125 ST
# 51  2017-08-14 15:06:31             0              M100  1 AV/125 ST
# 52  2017-08-14 16:46:25             0              M100  1 AV/125 ST
# 53  2017-08-14 18:06:23             0              M100  1 AV/125 ST
# 54  2017-08-14 18:46:07             0              M100  1 AV/125 ST
# 55  2017-08-15 10:07:05             0              M100  1 AV/125 ST
# 56  2017-08-15 13:27:34             0              M100  1 AV/125 ST
# 57  2017-08-15 15:57:42             0              M100  1 AV/125 ST
# 58  2017-08-16 09:29:21             0              M100  1 AV/125 ST
# 59  2017-08-16 16:19:41             0              M100  1 AV/125 ST
#
#     OriginLat  OriginLong                       DestinationName  \
# 50  40.801968  -73.931358  INWOOD 220 ST via AMSTERDAM via BWAY
# 51  40.801968  -73.931358  INWOOD 220 ST via AMSTERDAM via BWAY
# ...

# %%
def findNextBus(passengerArrival, mta_df):
    for index, row in mta_df.iterrows():
        if (pd.to_datetime(row['RecordedAtTime']) > passengerArrival[1]):
            return pd.to_datetime(row['RecordedAtTime'])

date_range = pd.date_range('2017-08-01', periods=60*24, freq='1min')
arrivals_df = pd.DataFrame()
arrivals_df['PassengerTime'] = i
arrivals_df['NextBus'] = findNextBus(arrivals_df['PassengerTime'], mta_df)
arrivals_df[900:925]
# Out:
#           PassengerTime             NextBus
# 900 2017-08-01 15:00:00 2017-08-01 07:51:49
# 901 2017-08-01 15:01:00 2017-08-01 07:51:49
# 902 2017-08-01 15:02:00 2017-08-01 07:51:49
# 903 2017-08-01 15:03:00 2017-08-01 07:51:49
# 904 2017-08-01 15:04:00 2017-08-01 07:51:49
# 905 2017-08-01 15:05:00 2017-08-01 07:51:49
# 906 2017-08-01 15:06:00 2017-08-01 07:51:49
# 907 2017-08-01 15:07:00 2017-08-01 07:51:49
# 908 2017-08-01 15:08:00 2017-08-01 07:51:49
# 909 2017-08-01 15:09:00 2017-08-01 07:51:49
# 910 2017-08-01 15:10:00 2017-08-01 07:51:49
# 911 2017-08-01 15:11:00 2017-08-01 07:51:49
# 912 2017-08-01 15:12:00 2017-08-01 07:51:49
# 913 2017-08-01 15:13:00 2017-08-01 07:51:49
# 914 2017-08-01 15:14:00 2017-08-01 07:51:49
# 915 2017-08-01 15:15:00 2017-08-01 07:51:49
# 916 2017-08-01 15:16:00 2017-08-01 07:51:49
# 917 2017-08-01 15:17:00 2017-08-01 07:51:49
# 918 2017-08-01 15:18:00 2017-08-01 07:51:49
# 919 2017-08-01 15:19:00 2017-08-01 07:51:49
# ...
