# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime, math

# %%
# %%capture
mta = pd.read_csv('mta_1708.csv', error_bad_lines=False)
# mta.set_index('PublishedLineName', inplace=True)
m100 = mta.loc[(mta['PublishedLineName']== 'M100') & (mta['DestinationName'] == 'INWOOD 220 ST via AMSTERDAM via BWAY'),]
arrivals = m100.loc[m100['ArrivalProximityText']=='at stop']
arrivals.head(20)

# %%
arrivals.head(20)
# Out:
#             RecordedAtTime  DirectionRef PublishedLineName   OriginName  \
# 1523   2017-08-01 00:11:39             0              M100  1 AV/125 ST
# 1762   2017-08-01 00:21:06             0              M100  1 AV/125 ST
# 3232   2017-08-01 00:41:29             0              M100  1 AV/125 ST
# 3850   2017-08-01 00:51:52             0              M100  1 AV/125 ST
# 4423   2017-08-01 01:01:11             0              M100  1 AV/125 ST
# 13699  2017-08-01 05:21:36             0              M100  1 AV/125 ST
# 13700  2017-08-01 05:21:36             0              M100  1 AV/125 ST
# 13701  2017-08-01 05:21:36             0              M100  1 AV/125 ST
# 14605  2017-08-01 05:31:39             0              M100  1 AV/125 ST
# 14606  2017-08-01 05:31:39             0              M100  1 AV/125 ST
# 14607  2017-08-01 05:31:39             0              M100  1 AV/125 ST
# 18114  2017-08-01 06:01:49             0              M100  1 AV/125 ST
# ...

# %%
new = arrivals.loc[:,['RecordedAtTime','VehicleRef']]

# %%
new.head()
# Out:
#           RecordedAtTime VehicleRef
# 1523 2017-08-01 00:11:39  NYCT_4349
# 1762 2017-08-01 00:21:06  NYCT_4368
# 3232 2017-08-01 00:41:29  NYCT_8375
# 3850 2017-08-01 00:51:52  NYCT_8375
# 4423 2017-08-01 01:01:11  NYCT_8375

# %% [markdown]
# mta.describe()

# %%
m100 = mta.loc[(mta['PublishedLineName']== 'M100') & (mta['DestinationName'] == 'INWOOD 220 ST via AMSTERDAM via BWAY'),]

# %%
arrivals = m100.loc[m100['ArrivalProximityText']=='at stop']
arrivals.head(20)

# %%
new = arrivals.loc[:,['RecordedAtTime','VehicleRef']].groupby(['VehicleRef','RecordedAtTime']).count()

new.head(20)

# %%
arrivals.info()

# %%
arrivals.RecordedAtTime =pd.to_datetime(arrivals.RecordedAtTime)
new.RecordedAtTime =pd.to_datetime(new.RecordedAtTime)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
new.RecordedAtTime =pd.to_datetime(new.RecordedAtTime)

# %%
def sub(row):
    return row['RecordedAtTime'] - row['RecordedAtTime']

# %%
new['Value'] = new.RecordedAtTime.diff()

# %%
new.head(100)
# Out:
#            RecordedAtTime VehicleRef             Value
# 1523  2017-08-01 00:11:39  NYCT_4349               NaT
# 1762  2017-08-01 00:21:06  NYCT_4368          00:09:27
# 3232  2017-08-01 00:41:29  NYCT_8375          00:20:23
# 3850  2017-08-01 00:51:52  NYCT_8375          00:10:23
# 4423  2017-08-01 01:01:11  NYCT_8375          00:09:19
# 13699 2017-08-01 05:21:36  NYCT_8368          04:20:25
# 13700 2017-08-01 05:21:36  NYCT_8368          00:00:00
# 13701 2017-08-01 05:21:36  NYCT_8368          00:00:00
# 14605 2017-08-01 05:31:39  NYCT_8368          00:10:03
# 14606 2017-08-01 05:31:39  NYCT_8368          00:00:00
# 14607 2017-08-01 05:31:39  NYCT_8368          00:00:00
# 18114 2017-08-01 06:01:49  NYCT_8368          00:30:10
# 18115 2017-08-01 06:01:49  NYCT_8368          00:00:00
# 18116 2017-08-01 06:01:49  NYCT_8368          00:00:00
# 20136 2017-08-01 06:11:35  NYCT_4348          00:09:46
# 20137 2017-08-01 06:11:35  NYCT_4348          00:00:00
# ...
